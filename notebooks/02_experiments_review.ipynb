# %% [markdown]
# 1. 02_experiments_review.ipynb
#
# L’idée de ce notebook, c’est :
#
# “J’ai lancé plusieurs expériences, qu’est-ce qui marche le mieux et pourquoi ?”
#
# Donc ici tu ne bosses pas sur un seul modèle, tu bosses sur l’historique de tes runs.
#
# Ce qu’on y met
#
# Par exemple :
#
# A. Charger le fichier de suivi des expériences
#
# Ton CSV avec :
#
# hypothèse
#
# paramètres
#
# preprocessing
#
# métriques
#
# chemin du modèle sauvegardé
#
# B. Afficher un tableau récapitulatif
#
# Exemple :
#
# run_id	hypothesis	img_size	normalize	pca	C	recall	precision	auc	train_auc
#
# Là, tu compares vite.
#
# C. Trier les expériences
#
# Par exemple :
#
# meilleure AUC test
#
# meilleur recall
#
# plus faible écart train/test
#
# meilleur compromis recall / precision
#
# D. Faire des graphes comparatifs
#
# Exemples :
#
# AUC par expérience
#
# Recall par expérience
#
# écart train_auc - test_auc
#
# impact de img_size
#
# impact de PCA
#
# impact de class_weight=balanced
#
# E. Écrire ton analyse expérimentale
#
# C’est là que tu racontes :
#
# pourquoi tu as essayé telle variation
#
# ce que ça a donné
#
# ce que tu en conclus
#
# quelle direction tu choisis pour la suite
